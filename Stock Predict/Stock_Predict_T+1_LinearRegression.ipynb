# %%
from __future__ import print_function
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import sys
from operator import add
from pyspark import SparkContext
from pyspark.mllib.regression import LinearRegressionWithSGD, LabeledPoint
from pyspark.mllib.classification import SVMWithSGD, SVMModel

import numpy as np
import csv
import math

#period: the days of period you choose
#✅WELL DONE
def get_csv_data(filename):
    filename = "file:/Users/nancywu/sparkhadoop/datatest/"+filename+".csv"
    File = sc.textFile(filename)
    File.map(lambda line: line.split(","))
    File.filter(lambda line: len(line) > 0)
    File.map(lambda line: (line[0], line[1]))

    data = File.collect()
    stock_text = [d.split(",") for d in data]

    #start date = 2016.4.1, means predict until this date and end, 
    #period= training period time= 90 days before predict day ,=n , n path which is in simulation program fucntion
    start, period = 1, 90
    training_period =90

    open_price_train = [float(stock_text[i][1]) for i in range(period+training_period+1 ,period+1, -1)]
    close_price_train = [float(stock_text[i][4]) for i in range(period+training_period+1 ,period+1,-1)]
    
    #相对于true_price前一天的数据集
    open_price = [float(stock_text[i][1]) for i in range (start+period,start,-1)]
    close_price = [float(stock_text[i][4]) for i in range (start+period,start,-1)]
    
    Date=["Date"]
    [Date.append(stock_text[i][0]) for i in range(start + period-1,start,-1)]
    
    True_price =True_price_train= ["True_price"]
    [True_price_train.append((float(stock_text[j][1])+float(stock_text[j][4]))*0.5) for j in range(period+training_period ,period, -1)]
    [True_price.append((float(stock_text[j][1])+float(stock_text[j][4]))*0.5) for j in range(start+period-1,start,-1)]
    print ("get_csv_data: done")
    #print ( open_price,close_price,S0,True_price)
    return open_price, close_price, open_price_train, close_price_train, True_price, True_price_train, Date


#NUMPY WRONG!!solved it already on Nov.28   ✅

def LinearRegression(filename):
    open_price, close_price, open_price_train, close_price_train, True_price,True_price_train, Date = get_csv_data(filename)
    output=[]
    for i in range(1,len(Date)):
        #features=训练集,这里可以自己调整去做尝试； label=target目标值
        #true_price_train与open_price, close_price一样都是前面90天的数据。trainin_period数据集
        #tmp = LabeledPoint(label=True_price_train[i],features=[open_price_train[i],close_price_train[i]])
        #tmp = LabeledPoint(label=True_price_train[i],features=[open_price_train[i]])
        ############
        ###########
        ##########需要修改
        tmp = LabeledPoint(label=True_price_train[i],features=[close_price_train[i]])
        output.append(tmp)
    output_train_data=sc.parallelize(output)                                                        
    output_model=LinearRegressionWithSGD.train(output_train_data,step=0.001,iterations=100000)
    return Date, True_price, output_model,open_price, close_price

def generation_output(Date, True_price,output_model,open_price, close_price):
    #Date=
    output = [["Date","Trueprice","Predictprice_upperbound","Predictprice_lowerbound"]]
    for i in range (1,len(Date)):
        S1=output_model.predict([open_price[i]])
        S2=output_model.predict([close_price[i]])
        tmp = [Date[i],True_price[i],S1,S2]
        output.append(tmp)
    return output
   

#Well done
def writeToElastic(fileindex,es,filename,stock_text):
    df=stock_text
    j = 1
    actions = []
    count = int(len(df))
    while (j < count):
        action = {
                   "_index": fileindex, # 这里不可以是大写，都是小写
                   "_type": filename,
                   "_id": j,
                   "_source": {
                               "date":df[j][0],
                               "trueprice":float(df[j][1]),
                               "predictprice_upper":float(df[j][2]),
                               "predictprice_lower":float(df[j][3]),
                               #"timestamp": datetime.now()
                                }
                   }
        print(action)
        actions.append(action)
        j += 1
        if (len(actions) == 180):
            helpers.bulk(es, actions)
            del actions[0:len(actions)]
            
    if (len(actions) >0 ):
            helpers.bulk(es, actions)
            del actions[0:len(actions)]
    

    
    
        
if __name__ =="__main__":
    #sc = SparkContext(appName="Monte Carlo")
    Ticker = sc.textFile("file:/Users/nancywu/sparkhadoop/datatest/Tickertest.csv")
    filelist = Ticker.map(lambda f: f.split(",")).collect()
    #l = Ticker.collect()
    #filelist = l[0].split(",")
    print(filelist)
    es = Elasticsearch()
    print("===========start============")
    for f in filelist:
        try:
            name = f[0]+".csv"
            print (name,"LinearRegression",f[0])
            Date, True_price, output_model, open_price, close_price = LinearRegression(f[0])
            print("=====LinearRegression pass=====")
            output = generation_output(Date, True_price,output_model,open_price, close_price)
            #9.25是今天的stock，预测的是t+1. 训练的时候进入的是t+1的值。则出来的是t+1; 👆训练的3个，所以这里是【10，6，7】
            #这里是3个features
            #print (output.predict([10,6,7]))
            print("=======output pass=======")
            print (output)
            sc.parallelize(output).repartition(1).saveAsTextFile("file:/Users/nancywu/sparkhadoop/datatest_result/" + name)
            writeToElastic("linerpredict",es,name,output)
        except:
            import traceback
            traceback.print_exc()
            print("No service for this stock")
# Out:
# [[u'AAPL']]
# ===========start============
# AAPL.csv LinearRegression AAPL
# get_csv_data: done
# =====LinearRegression pass=====
# =======output pass=======
# [['Date', 'Trueprice', 'Predictprice_upperbound', 'Predictprice_lowerbound'], [u'2015-11-20', 128.1249965, 119.19696389374003, 119.29696734903507], [u'2015-11-23', 129.3499985, 119.26696211255343, 117.74700378967198], [u'2015-11-24', 131.520004, 117.32701647674072, 118.87697203630738], [u'2015-11-25', 131.800003, 119.20696563923391, 118.026995664951], [u'2015-11-27', 123.60499949999999, 118.28699104906414, 117.80700026299149], [u'2015-11-30', 125.6800005, 117.98699568279736, 118.29699279455802], [u'2015-12-01', 124.91, 118.74697834414903, 117.33701022243817], [u'2015-12-02', 122.9299965, 117.33701022243817, 116.27704019461618], [u'2015-12-03', 123.379997, 116.5470373242232, 115.19706567583185], [u'2015-12-04', 123.07, 115.28706738563301, 119.02697021942805], [u'2015-12-07', 122.3450015, 118.9769754916024, 118.27698930357026], [u'2015-12-08', 121.9500005, 117.5170066422186, 118.22699457574463], [u'2015-12-09', 119.970001, 117.63700558870495, 115.61706098855953], [u'2015-12-10', 116.0299985, 116.0370483014908, 116.16704199364915], [u'2015-12-11', 114.1749995, 115.18707093015986, 113.1771200757119], [u'2015-12-14', 115.549999, 112.17714552123485, 112.47714088750162], [u'2015-12-15', 115.0499995, 111.93715362810947, 110.48718652421952], [u'2015-12-16', 118.125, 111.06717376576532, 111.3371628955759], [u'2015-12-17', 115.649998, 112.01714659259486, 108.97722994683195], [u'2015-12-18', 113.8849985, 108.90723272799313, 106.02730101122647], [u'2015-12-21', 115.5950015, 107.27726920432278, 107.32727093197028], [u'2015-12-22', 115.13999949999999, 107.39726915078369, 107.22727447649713], [u'2015-12-23', 116.6000025, 107.2672674588289, 108.60723736172635], [u'2015-12-24', 116.465, 108.99722643799784, 108.02725012018055], [u'2015-12-28', 115.555, 107.58725831628699, 106.81728190923788], [u'2015-12-29', 113.365002, 106.95727734689011, 108.7372310538847], [u'2015-12-30', 108.095001, 108.57723912506658, 107.31726918647639], [u'2015-12-31', 98.995003, 107.00727907453764, 105.25732360420281], [u'2016-01-04', 107.4249995, 102.60739003486408, 105.34731731420752], [u'2016-01-05', 108.389999, 105.74730913594745, 102.70738549036267], [u'2016-01-06', 112.5750005, 100.55743919826247, 100.6974346359147], [u'2016-01-07', 112.7299995, 98.67748903579475, 96.447542779387263], [u'2016-01-08', 112.39500050000001, 98.547495343636399, 96.957531802119675], [u'2016-01-11', 108.9350015, 98.96748265656764, 98.527491852648637], [u'2016-01-12', 111.2849995, 100.54744445259048, 99.957455465550808], [u'2016-01-13', 111.4300005, 100.31744730513709, 97.387520860544811], [u'2016-01-14', 109.119999, 97.95750635659671, 99.517464661631806], [u'2016-01-15', 112.029999, 96.197549140768004, 97.127525476431657], [u'2016-01-19', 111.95500200000001, 98.407499905984153, 96.657544435649328], [u'2016-01-20', 111.41999849999999, 95.097578130817809, 96.787538127807693], [u'2016-01-21', 113.0, 97.057528257592821, 96.297552596063042], [u'2016-01-22', 115.945, 98.627487308147224, 101.41741731511274], [u'2016-01-25', 116.1049995, 101.51741377058589, 99.437471697146407], [u'2016-01-26', 116.33000200000001, 99.927457228891058, 99.987453702210559], [u'2016-01-27', 114.790001, 96.037557211949903, 93.417620879296393], [u'2016-01-28', 112.82999799999999, 93.78761446437656, 94.087601830846893], [u'2016-01-29', 114.4399985, 94.787589018853595, 97.337519132897285], [u'2016-02-01', 113.3899995, 96.467546270375024, 96.427546288221407], [u'2016-02-02', 113.9749985, 95.417569988250477, 94.477598906914821], [u'2016-02-03', 114.125, 94.997582675319222, 96.347546323914116], [u'2016-02-04', 115.5750005, 95.857561792144026, 96.597539962533375], [u'2016-02-05', 113.14500000000001, 96.517540998200673, 94.017604612008057], [u'2016-02-08', 110.945, 93.127627258523489, 95.007584420813103], [u'2016-02-09', 110.23500050000001, 94.287601741615077, 94.987580929825342], [u'2016-02-10', 109.32500099999999, 95.917557265488995, 94.267598250627316], [u'2016-02-11', 109.1949995, 93.78761446437656, 93.697612754575388], [u ...
# {'_type': u'AAPL.csv', '_id': 1, '_source': {'date': u'2015-11-20', 'predictprice_upper': 119.19696389374003, 'predictprice_lower': 119.29696734903507, 'trueprice': 128.1249965}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 2, '_source': {'date': u'2015-11-23', 'predictprice_upper': 119.26696211255343, 'predictprice_lower': 117.74700378967198, 'trueprice': 129.3499985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 3, '_source': {'date': u'2015-11-24', 'predictprice_upper': 117.32701647674072, 'predictprice_lower': 118.87697203630738, 'trueprice': 131.520004}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 4, '_source': {'date': u'2015-11-25', 'predictprice_upper': 119.20696563923391, 'predictprice_lower': 118.026995664951, 'trueprice': 131.800003}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 5, '_source': {'date': u'2015-11-27', 'predictprice_upper': 118.28699104906414, 'predictprice_lower': 117.8070002629915, 'trueprice': 123.60499949999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 6, '_source': {'date': u'2015-11-30', 'predictprice_upper': 117.98699568279736, 'predictprice_lower': 118.29699279455802, 'trueprice': 125.6800005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 7, '_source': {'date': u'2015-12-01', 'predictprice_upper': 118.74697834414903, 'predictprice_lower': 117.33701022243817, 'trueprice': 124.91}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 8, '_source': {'date': u'2015-12-02', 'predictprice_upper': 117.33701022243817, 'predictprice_lower': 116.27704019461618, 'trueprice': 122.9299965}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 9, '_source': {'date': u'2015-12-03', 'predictprice_upper': 116.5470373242232, 'predictprice_lower': 115.19706567583185, 'trueprice': 123.379997}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 10, '_source': {'date': u'2015-12-04', 'predictprice_upper': 115.28706738563301, 'predictprice_lower': 119.02697021942805, 'trueprice': 123.07}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 11, '_source': {'date': u'2015-12-07', 'predictprice_upper': 118.9769754916024, 'predictprice_lower': 118.27698930357026, 'trueprice': 122.3450015}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 12, '_source': {'date': u'2015-12-08', 'predictprice_upper': 117.5170066422186, 'predictprice_lower': 118.22699457574463, 'trueprice': 121.9500005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 13, '_source': {'date': u'2015-12-09', 'predictprice_upper': 117.63700558870495, 'predictprice_lower': 115.61706098855953, 'trueprice': 119.970001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 14, '_source': {'date': u'2015-12-10', 'predictprice_upper': 116.0370483014908, 'predictprice_lower': 116.16704199364915, 'trueprice': 116.0299985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 15, '_source': {'date': u'2015-12-11', 'predictprice_upper': 115.18707093015986, 'predictprice_lower': 113.1771200757119, 'trueprice': 114.1749995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 16, '_source': {'date': u'2015-12-14', 'predictprice_upper': 112.17714552123485, 'predictprice_lower': 112.47714088750162, 'trueprice': 115.549999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 17, '_source': {'date': u'2015-12-15', 'predictprice_upper': 111.93715362810947, 'predictprice_lower': 110.48718652421952, 'trueprice': 115.0499995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 18, '_source': {'date': u'2015-12-16', 'predictprice_upper': 111.06717376576532, 'predictprice_lower': 111.3371628955759, 'trueprice': 118.125}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 19, '_source': {'date': u'2015-12-17', 'predictprice_upper': 112.01714659259486, 'predictprice_lower': 108.97722994683195, 'trueprice': 115.649998}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 20, '_source': {'date': u'2015-12-18', 'predictprice_upper': 108.90723272799313, 'predictprice_lower': 106.02730101122647, 'trueprice': 113.8849985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 21, '_source': {'date': u'2015-12-21', 'predictprice_upper': 107.27726920432278, 'predictprice_lower': 107.32727093197028, 'trueprice': 115.5950015}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 22, '_source': {'date': u'2015-12-22', 'predictprice_upper': 107.39726915078369, 'predictprice_lower': 107.22727447649713, 'trueprice': 115.13999949999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 23, '_source': {'date': u'2015-12-23', 'predictprice_upper': 107.2672674588289, 'predictprice_lower': 108.60723736172635, 'trueprice': 116.6000025}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 24, '_source': {'date': u'2015-12-24', 'predictprice_upper': 108.99722643799784, 'predictprice_lower': 108.02725012018055, 'trueprice': 116.465}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 25, '_source': {'date': u'2015-12-28', 'predictprice_upper': 107.58725831628699, 'predictprice_lower': 106.81728190923788, 'trueprice': 115.555}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 26, '_source': {'date': u'2015-12-29', 'predictprice_upper': 106.95727734689011, 'predictprice_lower': 108.7372310538847, 'trueprice': 113.365002}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 27, '_source': {'date': u'2015-12-30', 'predictprice_upper': 108.57723912506658, 'predictprice_lower': 107.3172691864764, 'trueprice': 108.095001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 28, '_source': {'date': u'2015-12-31', 'predictprice_upper': 107.00727907453764, 'predictprice_lower': 105.25732360420281, 'trueprice': 98.995003}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 29, '_source': {'date': u'2016-01-04', 'predictprice_upper': 102.60739003486408, 'predictprice_lower': 105.34731731420752, 'trueprice': 107.4249995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 30, '_source': {'date': u'2016-01-05', 'predictprice_upper': 105.74730913594745, 'predictprice_lower': 102.70738549036267, 'trueprice': 108.389999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 31, '_source': {'date': u'2016-01-06', 'predictprice_upper': 100.55743919826247, 'predictprice_lower': 100.6974346359147, 'trueprice': 112.5750005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 32, '_source': {'date': u'2016-01-07', 'predictprice_upper': 98.67748903579475, 'predictprice_lower': 96.44754277938726, 'trueprice': 112.7299995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 33, '_source': {'date': u'2016-01-08', 'predictprice_upper': 98.5474953436364, 'predictprice_lower': 96.95753180211968, 'trueprice': 112.39500050000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 34, '_source': {'date': u'2016-01-11', 'predictprice_upper': 98.96748265656764, 'predictprice_lower': 98.52749185264864, 'trueprice': 108.9350015}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 35, '_source': {'date': u'2016-01-12', 'predictprice_upper': 100.54744445259048, 'predictprice_lower': 99.95745546555081, 'trueprice': 111.2849995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 36, '_source': {'date': u'2016-01-13', 'predictprice_upper': 100.3174473051371, 'predictprice_lower': 97.38752086054481, 'trueprice': 111.4300005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 37, '_source': {'date': u'2016-01-14', 'predictprice_upper': 97.95750635659671, 'predictprice_lower': 99.5174646616318, 'trueprice': 109.119999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 38, '_source': {'date': u'2016-01-15', 'predictprice_upper': 96.197549140768, 'predictprice_lower': 97.12752547643166, 'trueprice': 112.029999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 39, '_source': {'date': u'2016-01-19', 'predictprice_upper': 98.40749990598415, 'predictprice_lower': 96.65754443564933, 'trueprice': 111.95500200000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 40, '_source': {'date': u'2016-01-20', 'predictprice_upper': 95.09757813081781, 'predictprice_lower': 96.7875381278077, 'trueprice': 111.41999849999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 41, '_source': {'date': u'2016-01-21', 'predictprice_upper': 97.05752825759282, 'predictprice_lower': 96.29755259606304, 'trueprice': 113.0}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 42, '_source': {'date': u'2016-01-22', 'predictprice_upper': 98.62748730814722, 'predictprice_lower': 101.41741731511274, 'trueprice': 115.945}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 43, '_source': {'date': u'2016-01-25', 'predictprice_upper': 101.51741377058589, 'predictprice_lower': 99.4374716971464, 'trueprice': 116.1049995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 44, '_source': {'date': u'2016-01-26', 'predictprice_upper': 99.92745722889106, 'predictprice_lower': 99.98745370221056, 'trueprice': 116.33000200000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 45, '_source': {'date': u'2016-01-27', 'predictprice_upper': 96.0375572119499, 'predictprice_lower': 93.4176208792964, 'trueprice': 114.790001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 46, '_source': {'date': u'2016-01-28', 'predictprice_upper': 93.78761446437656, 'predictprice_lower': 94.08760183084689, 'trueprice': 112.82999799999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 47, '_source': {'date': u'2016-01-29', 'predictprice_upper': 94.7875890188536, 'predictprice_lower': 97.33751913289728, 'trueprice': 114.4399985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 48, '_source': {'date': u'2016-02-01', 'predictprice_upper': 96.46754627037502, 'predictprice_lower': 96.42754628822141, 'trueprice': 113.3899995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 49, '_source': {'date': u'2016-02-02', 'predictprice_upper': 95.41756998825048, 'predictprice_lower': 94.47759890691482, 'trueprice': 113.9749985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 50, '_source': {'date': u'2016-02-03', 'predictprice_upper': 94.99758267531922, 'predictprice_lower': 96.34754632391412, 'trueprice': 114.125}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 51, '_source': {'date': u'2016-02-04', 'predictprice_upper': 95.85756179214403, 'predictprice_lower': 96.59753996253338, 'trueprice': 115.5750005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 52, '_source': {'date': u'2016-02-05', 'predictprice_upper': 96.51754099820067, 'predictprice_lower': 94.01760461200806, 'trueprice': 113.14500000000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 53, '_source': {'date': u'2016-02-08', 'predictprice_upper': 93.12762725852349, 'predictprice_lower': 95.0075844208131, 'trueprice': 110.945}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 54, '_source': {'date': u'2016-02-09', 'predictprice_upper': 94.28760174161508, 'predictprice_lower': 94.98758092982534, 'trueprice': 110.23500050000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 55, '_source': {'date': u'2016-02-10', 'predictprice_upper': 95.917557265489, 'predictprice_lower': 94.26759825062732, 'trueprice': 109.32500099999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 56, '_source': {'date': u'2016-02-11', 'predictprice_upper': 93.78761446437656, 'predictprice_lower': 93.69761275457539, 'trueprice': 109.1949995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 57, '_source': {'date': u'2016-02-12', 'predictprice_upper': 94.18760528614193, 'predictprice_lower': 93.98760637534829, 'trueprice': 110.329998}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 58, '_source': {'date': u'2016-02-16', 'predictprice_upper': 95.0175791664851, 'predictprice_lower': 96.63753994468702, 'trueprice': 110.9699975}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 59, '_source': {'date': u'2016-02-17', 'predictprice_upper': 96.66753818134679, 'predictprice_lower': 98.11750628521126, 'trueprice': 111.2599985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 60, '_source': {'date': u'2016-02-18', 'predictprice_upper': 98.83748096461285, 'predictprice_lower': 96.25755261390941, 'trueprice': 109.845001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 61, '_source': {'date': u'2016-02-19', 'predictprice_upper': 95.99755722979626, 'predictprice_lower': 96.0375572119499, 'trueprice': 111.0600015}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 62, '_source': {'date': u'2016-02-22', 'predictprice_upper': 96.30754734173503, 'predictprice_lower': 96.8775318378124, 'trueprice': 112.16500049999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 63, '_source': {'date': u'2016-02-23', 'predictprice_upper': 96.39754905153619, 'predictprice_lower': 94.68759256338045, 'trueprice': 111.3050005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 64, '_source': {'date': u'2016-02-24', 'predictprice_upper': 93.97761162967629, 'predictprice_lower': 96.09755268529486, 'trueprice': 110.75}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 65, '_source': {'date': u'2016-02-25', 'predictprice_upper': 96.04755895744378, 'predictprice_lower': 96.75753989114793, 'trueprice': 111.39500050000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 66, '_source': {'date': u'2016-02-26', 'predictprice_upper': 97.19752369524505, 'predictprice_lower': 96.90753807426859, 'trueprice': 111.41}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 67, '_source': {'date': u'2016-02-29', 'predictprice_upper': 96.85753634662107, 'predictprice_lower': 96.68754167233455, 'trueprice': 111.26500300000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 68, '_source': {'date': u'2016-03-01', 'predictprice_upper': 97.6475172446325, 'predictprice_lower': 100.52744096160272, 'trueprice': 112.5549965}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 69, '_source': {'date': u'2016-03-02', 'predictprice_upper': 100.50744447043684, 'predictprice_lower': 100.74743636356223, 'trueprice': 113.880001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 70, '_source': {'date': u'2016-03-03', 'predictprice_upper': 100.57744268925023, 'predictprice_lower': 101.49741727942, 'trueprice': 114.91500099999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 71, '_source': {'date': u'2016-03-04', 'predictprice_upper': 102.3673981417387, 'predictprice_lower': 103.00738085662945, 'trueprice': 117.88999949999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 72, '_source': {'date': u'2016-03-07', 'predictprice_upper': 102.38739363293003, 'predictprice_lower': 101.86741086450017, 'trueprice': 116.6800005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 73, '_source': {'date': u'2016-03-08', 'predictprice_upper': 100.77743460022198, 'predictprice_lower': 101.02742823884125, 'trueprice': 114.9750025}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 74, '_source': {'date': u'2016-03-09', 'predictprice_upper': 101.30742011412025, 'predictprice_lower': 101.1174299486424, 'trueprice': 118.0999985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 75, '_source': {'date': u'2016-03-10', 'predictprice_upper': 101.40742356941529, 'predictprice_lower': 101.16742367649348, 'trueprice': 119.614998}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 76, '_source': {'date': u'2016-03-11', 'predictprice_upper': 102.23739644978392, 'predictprice_lower': 102.25739994077168, 'trueprice': 120.244999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 77, '_source': {'date': u'2016-03-14', 'predictprice_upper': 101.90741084665382, 'predictprice_lower': 102.51738832506294, 'trueprice': 120.9900015}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 78, '_source': {'date': u'2016-03-15', 'predictprice_upper': 103.95735368345898, 'predictprice_lower': 104.5773409071584, 'trueprice': 121.6800005}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 79, '_source': {'date': u'2016-03-16', 'predictprice_upper': 104.60733914381817, 'predictprice_lower': 105.96730453790695, 'trueprice': 122.5649985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 80, '_source': {'date': u'2016-03-17', 'predictprice_upper': 105.51731198849407, 'predictprice_lower': 105.79731086359497, 'trueprice': 121.384998}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 81, '_source': {'date': u'2016-03-18', 'predictprice_upper': 106.33729012319068, 'predictprice_lower': 105.91730281025944, 'trueprice': 121.0849995}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 82, '_source': {'date': u'2016-03-21', 'predictprice_upper': 105.92730455575332, 'predictprice_lower': 105.907309064562, 'trueprice': 120.76499949999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 83, '_source': {'date': u'2016-03-22', 'predictprice_upper': 105.24732185870893, 'predictprice_lower': 106.71728545376473, 'trueprice': 116.83499950000001}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 84, '_source': {'date': u'2016-03-23', 'predictprice_upper': 106.47729356063935, 'predictprice_lower': 106.12729646672507, 'trueprice': 116.240002}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 85, '_source': {'date': u'2016-03-24', 'predictprice_upper': 105.46731726066842, 'predictprice_lower': 105.66730917164018, 'trueprice': 115.9900015}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 86, '_source': {'date': u'2016-03-28', 'predictprice_upper': 105.9973027745667, 'predictprice_lower': 105.18732538538941, 'trueprice': 113.76999649999999}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 87, '_source': {'date': u'2016-03-29', 'predictprice_upper': 104.88733001912264, 'predictprice_lower': 107.67726002608815, 'trueprice': 112.7799985}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 88, '_source': {'date': u'2016-03-30', 'predictprice_upper': 108.64723734387998, 'predictprice_lower': 109.55721018855587, 'trueprice': 114.305}, '_index': 'linerpredict'}
# {'_type': u'AAPL.csv', '_id': 89, '_source': {'date': u'2016-03-31', 'predictprice_upper': 109.71720911719586, 'predictprice_lower': 108.98722469250396, 'trueprice': 116.5250015}, '_index': 'linerpredict'}

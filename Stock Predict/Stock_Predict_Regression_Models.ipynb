# %%
#Author:NancyWU
#Date: Dec, 13th
#Function Description: 4 Model building/ Estimate/ Find the most least error to do stock prediction
#Regression models (Spark MLlib):
#   LinearRegression
#	DecisionTree
#	RandomForest
#	GradientBoostedTrees
#


from __future__ import print_function
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import sys
from operator import add
from pyspark import SparkContext
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel
from pyspark.mllib.regression import LinearRegressionModel, LinearRegressionWithSGD
from pyspark.mllib.tree import RandomForest, RandomForestModel
from pyspark.mllib.tree import GradientBoostedTrees, GradientBoostedTreesModel
from pyspark.mllib.regression import IsotonicRegression, IsotonicRegressionModel
from pyspark.mllib.regression import LabeledPoint

import numpy as np
import csv
import math

#period: the days of period you choose
#✅WELL DONE
def get_csv_data(filename):
    filename = "file:/Users/nancywu/sparkhadoop/datatest/"+filename+".csv"
    File = sc.textFile(filename)
    File.map(lambda line: line.split(","))
    File.filter(lambda line: len(line) > 0)
    File.map(lambda line: (line[0], line[1]))

    data = File.collect()
    stock_text = [d.split(",") for d in data]

    #start date = 2016.4.1, means predict until this date and end, 
    #period= training period time= 90 days before predict day ,=n , n path which is in simulation program fucntion
    start, period = 1, 90
    training_period =90

    open_price_train = [float(stock_text[i][1]) for i in range(period+training_period+1 ,period+1, -1)]
    close_price_train = [float(stock_text[i][4]) for i in range(period+training_period+1 ,period+1,-1)]
    
    #相对于true_price前一天的数据集
    open_price = [float(stock_text[i][1]) for i in range (start+period,start,-1)]
    close_price = [float(stock_text[i][4]) for i in range (start+period,start,-1)]
    
    Date=["Date"]
    [Date.append(stock_text[i][0]) for i in range(start + period-1,start,-1)]
    
    True_price =True_price_train= ["True_price"]
    [True_price_train.append((float(stock_text[j][1])+float(stock_text[j][4]))*0.5) for j in range(period+training_period ,period, -1)]
    [True_price.append((float(stock_text[j][1])+float(stock_text[j][4]))*0.5) for j in range(start+period-1,start,-1)]
    print ("get_csv_data: done")
    #print ( open_price,close_price,S0,True_price)
    return open_price, close_price, open_price_train, close_price_train, True_price, True_price_train, Date


#features=训练集,这里可以自己调整去做尝试； label=target目标值
#true_price_train与open_price, close_price一样都是前面90天的数据。trainin_period数据集
#tmp = LabeledPoint(label=True_price_train[i],features=[open_price_train[i],close_price_train[i]])
def Regression_Model(filename):
    open_price, close_price, open_price_train, close_price_train, True_price,True_price_train, Date = get_csv_data(filename)
    output=[]
    for i in range(1,len(Date)):
        tmp = LabeledPoint(label=True_price_train[i],features=[close_price_train[i]])
        output.append(tmp)
        
    output_train_RDD=sc.parallelize(output).cache()                                                          
    lrm=LinearRegressionWithSGD.train(output_train_RDD,step=0.001,iterations=100000)
    tree = DecisionTree.trainRegressor(output_train_RDD, categoricalFeaturesInfo={},impurity='variance', maxDepth=5, maxBins=30)
    forest = RandomForest.trainRegressor(output_train_RDD, categoricalFeaturesInfo={}, numTrees=3, featureSubsetStrategy="auto", impurity='variance', maxDepth=5, maxBins=30)
    gradient = GradientBoostedTrees.trainRegressor(output_train_RDD, categoricalFeaturesInfo={}, numIterations=10)
    
    print ("\n============MODEL Evaluation=============\n")
    model_name = ['LinearRegression','DecisionTree','RandomForest','GradientBoostedTrees']
    es_modelname=['lrm','tree','forest','gradient']
    result = ''
    x = 0
    err=1000
    test_model='LinearRegression'
    output_model_RDD=lrm
    for model in [lrm, tree, forest, gradient]:
        predictions = model.predict(output_train_RDD.map(lambda x: x.features))
        labelsAndPredictions = output_train_RDD.map(lambda lp: lp.label).zip(predictions)
        MSE = (labelsAndPredictions.map(lambda (v, p): (v - p) * (v - p)).sum() /float(output_train_RDD.count()))**0.5
        #print ("Predictions: ", valuesAndPreds.take(10))
        result += model_name[x] + "\tMean Squared Error\t=" + str(MSE) + "\n"
        if (err>MSE):
            err=MSE
            output_model=model
            es_model=es_modelname[x]
        x += 1
    print (result)
    print (es_model)
    return Date, True_price, output_model_RDD, open_price, close_price, es_model

def generation_output(stock_name):
    Date, True_price, output_model_RDD, open_price, close_price,modelname = Regression_Model(stock_name)
    output = [["Date","Trueprice","Predictprice"]]
    for i in range (1,len(Date)):
        #S1=output_model.predict([open_price[i]])
        S1=output_model_RDD.predict([close_price[i]])
        tmp = [Date[i],True_price[i],S1]
        output.append(tmp)
    return output,modelname
   

#Well done
def writeToElastic(fileindex,modelname,es,filename,stock_text):
    df=stock_text
    j = 1
    actions = []
    count = int(len(df))
    while (j < count):
        action = {
                   "_index": fileindex, # 这里不可以是大写，都是小写
                   "_type": filename,
                   "_id": j,
                   "_source": {
                               "date":df[j][0],
                               "trueprice":float(df[j][1]),
                               "predictprice":float(df[j][2]),
                               "regressionmodel":str(modelname)
                                }
                   }
        print(action)
        actions.append(action)
        j += 1
        if (len(actions) == 180):
            helpers.bulk(es, actions)
            del actions[0:len(actions)]
            
    if (len(actions) >0 ):
            helpers.bulk(es, actions)
            del actions[0:len(actions)]
    
        
if __name__ =="__main__":
    #sc = SparkContext(appName="Monte Carlo")
    Ticker = sc.textFile("file:/Users/nancywu/sparkhadoop/datatest/Tickertest.csv")
    filelist = Ticker.map(lambda f: f.split(",")).collect()
    #l = Ticker.collect()
    #filelist = l[0].split(",")
    print(filelist)
    es = Elasticsearch(["http://127.0.0.1:9200"])
    print("===========start============")
    for f in filelist:
        try:
            name = f[0]+".csv"
            output_predict,modelname = generation_output(f[0])
            print("=======output pass=======")
            #sc.parallelize(output_predict).repartition(1).saveAsTextFile("file:/Users/nancywu/sparkhadoop/datatest_result/" + name)
            writeToElastic('regressionpredict',modelname,es,name,output_predict)
            print("=======es writing pass=======")
        except:
            import traceback
            traceback.print_exc()
            print("No service for this stock")
# Out:
# [[u'AA'], [u'AAPL']]
# ===========start============
# get_csv_data: done
#
# ============MODEL Evaluation=============
#
# LinearRegression	Mean Squared Error	=1.25273471323
# DecisionTree	Mean Squared Error	=0.10771724847
# RandomForest	Mean Squared Error	=0.115083648321
# GradientBoostedTrees	Mean Squared Error	=0.122672466421
#
# tree
# =======output pass=======
# {'_type': u'AA.csv', '_id': 1, '_source': {'date': u'2015-11-20', 'regressionmodel': 'tree', 'predictprice': 7.553500438614603, 'trueprice': 10.58}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 2, '_source': {'date': u'2015-11-23', 'regressionmodel': 'tree', 'predictprice': 7.883803104514897, 'trueprice': 10.49}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 3, '_source': {'date': u'2015-11-24', 'regressionmodel': 'tree', 'predictprice': 7.901187455351754, 'trueprice': 10.325}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 4, '_source': {'date': u'2015-11-25', 'regressionmodel': 'tree', 'predictprice': 8.179337068741475, 'trueprice': 10.215}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 5, '_source': {'date': u'2015-11-27', 'regressionmodel': 'tree', 'predictprice': 8.101107489975616, 'trueprice': 10.075}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 6, '_source': {'date': u'2015-11-30', 'regressionmodel': 'tree', 'predictprice': 8.13587619164933, 'trueprice': 10.025}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 7, '_source': {'date': u'2015-12-01', 'regressionmodel': 'tree', 'predictprice': 8.240182296670477, 'trueprice': 9.86}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 8, '_source': {'date': u'2015-12-02', 'regressionmodel': 'tree', 'predictprice': 8.127184016230903, 'trueprice': 9.665}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 9, '_source': {'date': u'2015-12-03', 'regressionmodel': 'tree', 'predictprice': 7.814265701167467, 'trueprice': 9.809999999999999}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 10, '_source': {'date': u'2015-12-04', 'regressionmodel': 'tree', 'predictprice': 8.118491840812473, 'trueprice': 10.04}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 11, '_source': {'date': u'2015-12-07', 'regressionmodel': 'tree', 'predictprice': 7.8577265782596095, 'trueprice': 10.085}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 12, '_source': {'date': u'2015-12-08', 'regressionmodel': 'tree', 'predictprice': 7.405733456501314, 'trueprice': 9.98}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 13, '_source': {'date': u'2015-12-09', 'regressionmodel': 'tree', 'predictprice': 7.596961315706747, 'trueprice': 9.73}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 14, '_source': {'date': u'2015-12-10', 'regressionmodel': 'tree', 'predictprice': 7.970724858699184, 'trueprice': 9.835}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 15, '_source': {'date': u'2015-12-11', 'regressionmodel': 'tree', 'predictprice': 7.701267420727892, 'trueprice': 9.835}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 16, '_source': {'date': u'2015-12-14', 'regressionmodel': 'tree', 'predictprice': 7.822957876585895, 'trueprice': 9.835}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 17, '_source': {'date': u'2015-12-15', 'regressionmodel': 'tree', 'predictprice': 7.92726398160704, 'trueprice': 9.615}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 18, '_source': {'date': u'2015-12-16', 'regressionmodel': 'tree', 'predictprice': 8.031570086628186, 'trueprice': 9.805}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 19, '_source': {'date': u'2015-12-17', 'regressionmodel': 'tree', 'predictprice': 7.953340507862327, 'trueprice': 9.59}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 20, '_source': {'date': u'2015-12-18', 'regressionmodel': 'tree', 'predictprice': 8.022877911209758, 'trueprice': 9.45}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 21, '_source': {'date': u'2015-12-21', 'regressionmodel': 'tree', 'predictprice': 8.101107489975616, 'trueprice': 9.415}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 22, '_source': {'date': u'2015-12-22', 'regressionmodel': 'tree', 'predictprice': 8.309719700017906, 'trueprice': 9.365}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 23, '_source': {'date': u'2015-12-23', 'regressionmodel': 'tree', 'predictprice': 8.857326751378919, 'trueprice': 9.370000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 24, '_source': {'date': u'2015-12-24', 'regressionmodel': 'tree', 'predictprice': 8.796481523449916, 'trueprice': 9.285}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 25, '_source': {'date': u'2015-12-28', 'regressionmodel': 'tree', 'predictprice': 8.674791067591915, 'trueprice': 9.145}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 26, '_source': {'date': u'2015-12-29', 'regressionmodel': 'tree', 'predictprice': 8.805173698868348, 'trueprice': 9.11}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 27, '_source': {'date': u'2015-12-30', 'regressionmodel': 'tree', 'predictprice': 8.657406716755059, 'trueprice': 8.850000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 28, '_source': {'date': u'2015-12-31', 'regressionmodel': 'tree', 'predictprice': 8.579177137989198, 'trueprice': 8.2}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 29, '_source': {'date': u'2016-01-04', 'regressionmodel': 'tree', 'predictprice': 8.440102331294339, 'trueprice': 8.370000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 30, '_source': {'date': u'2016-01-05', 'regressionmodel': 'tree', 'predictprice': 8.057646612883472, 'trueprice': 8.26}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 31, '_source': {'date': u'2016-01-06', 'regressionmodel': 'tree', 'predictprice': 7.483963035267172, 'trueprice': 8.629999999999999}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 32, '_source': {'date': u'2016-01-07', 'regressionmodel': 'tree', 'predictprice': 7.188429071040595, 'trueprice': 9.145}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 33, '_source': {'date': u'2016-01-08', 'regressionmodel': 'tree', 'predictprice': 7.0145855626720195, 'trueprice': 9.36}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 34, '_source': {'date': u'2016-01-11', 'regressionmodel': 'tree', 'predictprice': 6.953740334743018, 'trueprice': 9.185}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 35, '_source': {'date': u'2016-01-12', 'regressionmodel': 'tree', 'predictprice': 6.327903704616147, 'trueprice': 9.355}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 36, '_source': {'date': u'2016-01-13', 'regressionmodel': 'tree', 'predictprice': 6.197521073339715, 'trueprice': 9.485}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 37, '_source': {'date': u'2016-01-14', 'regressionmodel': 'tree', 'predictprice': 6.2931350029424316, 'trueprice': 9.440000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 38, '_source': {'date': u'2016-01-15', 'regressionmodel': 'tree', 'predictprice': 5.997601038715853, 'trueprice': 9.795}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 39, '_source': {'date': u'2016-01-19', 'regressionmodel': 'tree', 'predictprice': 5.858526232020993, 'trueprice': 9.745000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 40, '_source': {'date': u'2016-01-20', 'regressionmodel': 'tree', 'predictprice': 5.858526232020993, 'trueprice': 9.595}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 41, '_source': {'date': u'2016-01-21', 'regressionmodel': 'tree', 'predictprice': 6.1627523716659995, 'trueprice': 9.625}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 42, '_source': {'date': u'2016-01-22', 'regressionmodel': 'tree', 'predictprice': 5.971524512460567, 'trueprice': 9.48}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 43, '_source': {'date': u'2016-01-25', 'regressionmodel': 'tree', 'predictprice': 5.910679284531565, 'trueprice': 9.510000000000002}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 44, '_source': {'date': u'2016-01-26', 'regressionmodel': 'tree', 'predictprice': 6.206213248758143, 'trueprice': 9.78}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 45, '_source': {'date': u'2016-01-27', 'regressionmodel': 'tree', 'predictprice': 6.049754091226426, 'trueprice': 9.879999999999999}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 46, '_source': {'date': u'2016-01-28', 'regressionmodel': 'tree', 'predictprice': 6.084522792900141, 'trueprice': 9.91}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 47, '_source': {'date': u'2016-01-29', 'regressionmodel': 'tree', 'predictprice': 6.336595880034575, 'trueprice': 9.940000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 48, '_source': {'date': u'2016-02-01', 'regressionmodel': 'tree', 'predictprice': 6.267058476687145, 'trueprice': 9.55}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 49, '_source': {'date': u'2016-02-02', 'regressionmodel': 'tree', 'predictprice': 6.058446266644855, 'trueprice': 9.39}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 50, '_source': {'date': u'2016-02-03', 'regressionmodel': 'tree', 'predictprice': 6.562592440913723, 'trueprice': 9.125}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 51, '_source': {'date': u'2016-02-04', 'regressionmodel': 'tree', 'predictprice': 7.22319777271431, 'trueprice': 9.16}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 52, '_source': {'date': u'2016-02-05', 'regressionmodel': 'tree', 'predictprice': 7.058046439764163, 'trueprice': 9.525}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 53, '_source': {'date': u'2016-02-08', 'regressionmodel': 'tree', 'predictprice': 6.86681858055873, 'trueprice': 9.535}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 54, '_source': {'date': u'2016-02-09', 'regressionmodel': 'tree', 'predictprice': 6.788589001792871, 'trueprice': 9.635}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 55, '_source': {'date': u'2016-02-10', 'regressionmodel': 'tree', 'predictprice': 6.553900265495295, 'trueprice': 9.485}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 56, '_source': {'date': u'2016-02-11', 'regressionmodel': 'tree', 'predictprice': 6.37136458170829, 'trueprice': 9.335}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 57, '_source': {'date': u'2016-02-12', 'regressionmodel': 'tree', 'predictprice': 6.684282896771727, 'trueprice': 10.01}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 58, '_source': {'date': u'2016-02-16', 'regressionmodel': 'tree', 'predictprice': 7.058046439764163, 'trueprice': 10.705}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 59, '_source': {'date': u'2016-02-17', 'regressionmodel': 'tree', 'predictprice': 7.405733456501314, 'trueprice': 11.045}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 60, '_source': {'date': u'2016-02-18', 'regressionmodel': 'tree', 'predictprice': 7.058046439764163, 'trueprice': 10.93}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 61, '_source': {'date': u'2016-02-19', 'regressionmodel': 'tree', 'predictprice': 6.840742054303444, 'trueprice': 10.465}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 62, '_source': {'date': u'2016-02-22', 'regressionmodel': 'tree', 'predictprice': 7.7447282978200365, 'trueprice': 10.18}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 63, '_source': {'date': u'2016-02-23', 'regressionmodel': 'tree', 'predictprice': 7.414425631919743, 'trueprice': 9.995000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 64, '_source': {'date': u'2016-02-24', 'regressionmodel': 'tree', 'predictprice': 7.6143456665436045, 'trueprice': 10.02}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 65, '_source': {'date': u'2016-02-25', 'regressionmodel': 'tree', 'predictprice': 7.70995959614632, 'trueprice': 9.815}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 66, '_source': {'date': u'2016-02-26', 'regressionmodel': 'tree', 'predictprice': 7.70995959614632, 'trueprice': 9.665}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 67, '_source': {'date': u'2016-02-29', 'regressionmodel': 'tree', 'predictprice': 7.762112648656894, 'trueprice': 9.425}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 68, '_source': {'date': u'2016-03-01', 'regressionmodel': 'tree', 'predictprice': 7.918571806188611, 'trueprice': 9.385}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 69, '_source': {'date': u'2016-03-02', 'regressionmodel': 'tree', 'predictprice': 8.361872752528479, 'trueprice': 9.25}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 70, '_source': {'date': u'2016-03-03', 'regressionmodel': 'tree', 'predictprice': 8.231490121252047, 'trueprice': 9.125}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 71, '_source': {'date': u'2016-03-04', 'regressionmodel': 'tree', 'predictprice': 8.318411875436336, 'trueprice': 9.15}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 72, '_source': {'date': u'2016-03-07', 'regressionmodel': 'tree', 'predictprice': 8.726944120102488, 'trueprice': 8.95}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 73, '_source': {'date': u'2016-03-08', 'regressionmodel': 'tree', 'predictprice': 8.109799665394045, 'trueprice': 8.76}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 74, '_source': {'date': u'2016-03-09', 'regressionmodel': 'tree', 'predictprice': 8.188029244159903, 'trueprice': 8.870000000000001}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 75, '_source': {'date': u'2016-03-10', 'regressionmodel': 'tree', 'predictprice': 8.335796226273192, 'trueprice': 8.925}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 76, '_source': {'date': u'2016-03-11', 'regressionmodel': 'tree', 'predictprice': 8.274950998344192, 'trueprice': 8.95}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 77, '_source': {'date': u'2016-03-14', 'regressionmodel': 'tree', 'predictprice': 8.405333629620623, 'trueprice': 9.059999999999999}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 78, '_source': {'date': u'2016-03-15', 'regressionmodel': 'tree', 'predictprice': 7.962032683280755, 'trueprice': 9.29}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 79, '_source': {'date': u'2016-03-16', 'regressionmodel': 'tree', 'predictprice': 8.466178857549625, 'trueprice': 9.415}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 80, '_source': {'date': u'2016-03-17', 'regressionmodel': 'tree', 'predictprice': 8.640022365918199, 'trueprice': 9.235}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 81, '_source': {'date': u'2016-03-18', 'regressionmodel': 'tree', 'predictprice': 8.718251944684058, 'trueprice': 9.1}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 82, '_source': {'date': u'2016-03-21', 'regressionmodel': 'tree', 'predictprice': 8.596561488826056, 'trueprice': 8.79}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 83, '_source': {'date': u'2016-03-22', 'regressionmodel': 'tree', 'predictprice': 8.56179278715234, 'trueprice': 8.475}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 84, '_source': {'date': u'2016-03-23', 'regressionmodel': 'tree', 'predictprice': 8.101107489975616, 'trueprice': 8.23}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 85, '_source': {'date': u'2016-03-24', 'regressionmodel': 'tree', 'predictprice': 8.318411875436336, 'trueprice': 7.91}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 86, '_source': {'date': u'2016-03-28', 'regressionmodel': 'tree', 'predictprice': 8.43141015587591, 'trueprice': 7.92}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 87, '_source': {'date': u'2016-03-29', 'regressionmodel': 'tree', 'predictprice': 8.448794506712767, 'trueprice': 8.129999999999999}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 88, '_source': {'date': u'2016-03-30', 'regressionmodel': 'tree', 'predictprice': 8.414025805039051, 'trueprice': 8.3}, '_index': 'regressionpredict'}
# {'_type': u'AA.csv', '_id': 89, '_source': {'date': u'2016-03-31', 'regressionmodel': 'tree', 'predictprice': 8.327104050854764, 'trueprice': 8.36}, '_index': 'regressionpredict'}
# =======es writing pass=======
# get_csv_data: done
#
# ============MODEL Evaluation=============
#
# LinearRegression	Mean Squared Error	=1.04742371274
# DecisionTree	Mean Squared Error	=1.10001321552
# RandomForest	Mean Squared Error	=1.15529496905
# GradientBoostedTrees	Mean Squared Error	=1.2092604089
#
# lrm
# =======output pass=======
# {'_type': u'AAPL.csv', '_id': 1, '_source': {'date': u'2015-11-20', 'regressionmodel': 'lrm', 'predictprice': 119.29696734903507, 'trueprice': 128.1249965}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 2, '_source': {'date': u'2015-11-23', 'regressionmodel': 'lrm', 'predictprice': 117.74700378967198, 'trueprice': 129.3499985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 3, '_source': {'date': u'2015-11-24', 'regressionmodel': 'lrm', 'predictprice': 118.87697203630738, 'trueprice': 131.520004}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 4, '_source': {'date': u'2015-11-25', 'regressionmodel': 'lrm', 'predictprice': 118.026995664951, 'trueprice': 131.800003}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 5, '_source': {'date': u'2015-11-27', 'regressionmodel': 'lrm', 'predictprice': 117.8070002629915, 'trueprice': 123.60499949999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 6, '_source': {'date': u'2015-11-30', 'regressionmodel': 'lrm', 'predictprice': 118.29699279455802, 'trueprice': 125.6800005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 7, '_source': {'date': u'2015-12-01', 'regressionmodel': 'lrm', 'predictprice': 117.33701022243817, 'trueprice': 124.91}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 8, '_source': {'date': u'2015-12-02', 'regressionmodel': 'lrm', 'predictprice': 116.27704019461618, 'trueprice': 122.9299965}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 9, '_source': {'date': u'2015-12-03', 'regressionmodel': 'lrm', 'predictprice': 115.19706567583185, 'trueprice': 123.379997}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 10, '_source': {'date': u'2015-12-04', 'regressionmodel': 'lrm', 'predictprice': 119.02697021942805, 'trueprice': 123.07}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 11, '_source': {'date': u'2015-12-07', 'regressionmodel': 'lrm', 'predictprice': 118.27698930357026, 'trueprice': 122.3450015}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 12, '_source': {'date': u'2015-12-08', 'regressionmodel': 'lrm', 'predictprice': 118.22699457574463, 'trueprice': 121.9500005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 13, '_source': {'date': u'2015-12-09', 'regressionmodel': 'lrm', 'predictprice': 115.61706098855953, 'trueprice': 119.970001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 14, '_source': {'date': u'2015-12-10', 'regressionmodel': 'lrm', 'predictprice': 116.16704199364915, 'trueprice': 116.0299985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 15, '_source': {'date': u'2015-12-11', 'regressionmodel': 'lrm', 'predictprice': 113.1771200757119, 'trueprice': 114.1749995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 16, '_source': {'date': u'2015-12-14', 'regressionmodel': 'lrm', 'predictprice': 112.47714088750162, 'trueprice': 115.549999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 17, '_source': {'date': u'2015-12-15', 'regressionmodel': 'lrm', 'predictprice': 110.48718652421952, 'trueprice': 115.0499995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 18, '_source': {'date': u'2015-12-16', 'regressionmodel': 'lrm', 'predictprice': 111.3371628955759, 'trueprice': 118.125}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 19, '_source': {'date': u'2015-12-17', 'regressionmodel': 'lrm', 'predictprice': 108.97722994683195, 'trueprice': 115.649998}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 20, '_source': {'date': u'2015-12-18', 'regressionmodel': 'lrm', 'predictprice': 106.02730101122647, 'trueprice': 113.8849985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 21, '_source': {'date': u'2015-12-21', 'regressionmodel': 'lrm', 'predictprice': 107.32727093197028, 'trueprice': 115.5950015}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 22, '_source': {'date': u'2015-12-22', 'regressionmodel': 'lrm', 'predictprice': 107.22727447649713, 'trueprice': 115.13999949999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 23, '_source': {'date': u'2015-12-23', 'regressionmodel': 'lrm', 'predictprice': 108.60723736172635, 'trueprice': 116.6000025}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 24, '_source': {'date': u'2015-12-24', 'regressionmodel': 'lrm', 'predictprice': 108.02725012018055, 'trueprice': 116.465}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 25, '_source': {'date': u'2015-12-28', 'regressionmodel': 'lrm', 'predictprice': 106.81728190923788, 'trueprice': 115.555}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 26, '_source': {'date': u'2015-12-29', 'regressionmodel': 'lrm', 'predictprice': 108.7372310538847, 'trueprice': 113.365002}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 27, '_source': {'date': u'2015-12-30', 'regressionmodel': 'lrm', 'predictprice': 107.3172691864764, 'trueprice': 108.095001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 28, '_source': {'date': u'2015-12-31', 'regressionmodel': 'lrm', 'predictprice': 105.25732360420281, 'trueprice': 98.995003}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 29, '_source': {'date': u'2016-01-04', 'regressionmodel': 'lrm', 'predictprice': 105.34731731420752, 'trueprice': 107.4249995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 30, '_source': {'date': u'2016-01-05', 'regressionmodel': 'lrm', 'predictprice': 102.70738549036267, 'trueprice': 108.389999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 31, '_source': {'date': u'2016-01-06', 'regressionmodel': 'lrm', 'predictprice': 100.6974346359147, 'trueprice': 112.5750005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 32, '_source': {'date': u'2016-01-07', 'regressionmodel': 'lrm', 'predictprice': 96.44754277938726, 'trueprice': 112.7299995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 33, '_source': {'date': u'2016-01-08', 'regressionmodel': 'lrm', 'predictprice': 96.95753180211968, 'trueprice': 112.39500050000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 34, '_source': {'date': u'2016-01-11', 'regressionmodel': 'lrm', 'predictprice': 98.52749185264864, 'trueprice': 108.9350015}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 35, '_source': {'date': u'2016-01-12', 'regressionmodel': 'lrm', 'predictprice': 99.95745546555081, 'trueprice': 111.2849995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 36, '_source': {'date': u'2016-01-13', 'regressionmodel': 'lrm', 'predictprice': 97.38752086054481, 'trueprice': 111.4300005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 37, '_source': {'date': u'2016-01-14', 'regressionmodel': 'lrm', 'predictprice': 99.5174646616318, 'trueprice': 109.119999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 38, '_source': {'date': u'2016-01-15', 'regressionmodel': 'lrm', 'predictprice': 97.12752547643166, 'trueprice': 112.029999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 39, '_source': {'date': u'2016-01-19', 'regressionmodel': 'lrm', 'predictprice': 96.65754443564933, 'trueprice': 111.95500200000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 40, '_source': {'date': u'2016-01-20', 'regressionmodel': 'lrm', 'predictprice': 96.7875381278077, 'trueprice': 111.41999849999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 41, '_source': {'date': u'2016-01-21', 'regressionmodel': 'lrm', 'predictprice': 96.29755259606304, 'trueprice': 113.0}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 42, '_source': {'date': u'2016-01-22', 'regressionmodel': 'lrm', 'predictprice': 101.41741731511274, 'trueprice': 115.945}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 43, '_source': {'date': u'2016-01-25', 'regressionmodel': 'lrm', 'predictprice': 99.4374716971464, 'trueprice': 116.1049995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 44, '_source': {'date': u'2016-01-26', 'regressionmodel': 'lrm', 'predictprice': 99.98745370221056, 'trueprice': 116.33000200000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 45, '_source': {'date': u'2016-01-27', 'regressionmodel': 'lrm', 'predictprice': 93.4176208792964, 'trueprice': 114.790001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 46, '_source': {'date': u'2016-01-28', 'regressionmodel': 'lrm', 'predictprice': 94.08760183084689, 'trueprice': 112.82999799999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 47, '_source': {'date': u'2016-01-29', 'regressionmodel': 'lrm', 'predictprice': 97.33751913289728, 'trueprice': 114.4399985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 48, '_source': {'date': u'2016-02-01', 'regressionmodel': 'lrm', 'predictprice': 96.42754628822141, 'trueprice': 113.3899995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 49, '_source': {'date': u'2016-02-02', 'regressionmodel': 'lrm', 'predictprice': 94.47759890691482, 'trueprice': 113.9749985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 50, '_source': {'date': u'2016-02-03', 'regressionmodel': 'lrm', 'predictprice': 96.34754632391412, 'trueprice': 114.125}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 51, '_source': {'date': u'2016-02-04', 'regressionmodel': 'lrm', 'predictprice': 96.59753996253338, 'trueprice': 115.5750005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 52, '_source': {'date': u'2016-02-05', 'regressionmodel': 'lrm', 'predictprice': 94.01760461200806, 'trueprice': 113.14500000000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 53, '_source': {'date': u'2016-02-08', 'regressionmodel': 'lrm', 'predictprice': 95.0075844208131, 'trueprice': 110.945}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 54, '_source': {'date': u'2016-02-09', 'regressionmodel': 'lrm', 'predictprice': 94.98758092982534, 'trueprice': 110.23500050000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 55, '_source': {'date': u'2016-02-10', 'regressionmodel': 'lrm', 'predictprice': 94.26759825062732, 'trueprice': 109.32500099999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 56, '_source': {'date': u'2016-02-11', 'regressionmodel': 'lrm', 'predictprice': 93.69761275457539, 'trueprice': 109.1949995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 57, '_source': {'date': u'2016-02-12', 'regressionmodel': 'lrm', 'predictprice': 93.98760637534829, 'trueprice': 110.329998}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 58, '_source': {'date': u'2016-02-16', 'regressionmodel': 'lrm', 'predictprice': 96.63753994468702, 'trueprice': 110.9699975}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 59, '_source': {'date': u'2016-02-17', 'regressionmodel': 'lrm', 'predictprice': 98.11750628521126, 'trueprice': 111.2599985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 60, '_source': {'date': u'2016-02-18', 'regressionmodel': 'lrm', 'predictprice': 96.25755261390941, 'trueprice': 109.845001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 61, '_source': {'date': u'2016-02-19', 'regressionmodel': 'lrm', 'predictprice': 96.0375572119499, 'trueprice': 111.0600015}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 62, '_source': {'date': u'2016-02-22', 'regressionmodel': 'lrm', 'predictprice': 96.8775318378124, 'trueprice': 112.16500049999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 63, '_source': {'date': u'2016-02-23', 'regressionmodel': 'lrm', 'predictprice': 94.68759256338045, 'trueprice': 111.3050005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 64, '_source': {'date': u'2016-02-24', 'regressionmodel': 'lrm', 'predictprice': 96.09755268529486, 'trueprice': 110.75}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 65, '_source': {'date': u'2016-02-25', 'regressionmodel': 'lrm', 'predictprice': 96.75753989114793, 'trueprice': 111.39500050000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 66, '_source': {'date': u'2016-02-26', 'regressionmodel': 'lrm', 'predictprice': 96.90753807426859, 'trueprice': 111.41}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 67, '_source': {'date': u'2016-02-29', 'regressionmodel': 'lrm', 'predictprice': 96.68754167233455, 'trueprice': 111.26500300000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 68, '_source': {'date': u'2016-03-01', 'regressionmodel': 'lrm', 'predictprice': 100.52744096160272, 'trueprice': 112.5549965}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 69, '_source': {'date': u'2016-03-02', 'regressionmodel': 'lrm', 'predictprice': 100.74743636356223, 'trueprice': 113.880001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 70, '_source': {'date': u'2016-03-03', 'regressionmodel': 'lrm', 'predictprice': 101.49741727942, 'trueprice': 114.91500099999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 71, '_source': {'date': u'2016-03-04', 'regressionmodel': 'lrm', 'predictprice': 103.00738085662945, 'trueprice': 117.88999949999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 72, '_source': {'date': u'2016-03-07', 'regressionmodel': 'lrm', 'predictprice': 101.86741086450017, 'trueprice': 116.6800005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 73, '_source': {'date': u'2016-03-08', 'regressionmodel': 'lrm', 'predictprice': 101.02742823884125, 'trueprice': 114.9750025}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 74, '_source': {'date': u'2016-03-09', 'regressionmodel': 'lrm', 'predictprice': 101.1174299486424, 'trueprice': 118.0999985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 75, '_source': {'date': u'2016-03-10', 'regressionmodel': 'lrm', 'predictprice': 101.16742367649348, 'trueprice': 119.614998}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 76, '_source': {'date': u'2016-03-11', 'regressionmodel': 'lrm', 'predictprice': 102.25739994077168, 'trueprice': 120.244999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 77, '_source': {'date': u'2016-03-14', 'regressionmodel': 'lrm', 'predictprice': 102.51738832506294, 'trueprice': 120.9900015}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 78, '_source': {'date': u'2016-03-15', 'regressionmodel': 'lrm', 'predictprice': 104.5773409071584, 'trueprice': 121.6800005}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 79, '_source': {'date': u'2016-03-16', 'regressionmodel': 'lrm', 'predictprice': 105.96730453790695, 'trueprice': 122.5649985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 80, '_source': {'date': u'2016-03-17', 'regressionmodel': 'lrm', 'predictprice': 105.79731086359497, 'trueprice': 121.384998}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 81, '_source': {'date': u'2016-03-18', 'regressionmodel': 'lrm', 'predictprice': 105.91730281025944, 'trueprice': 121.0849995}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 82, '_source': {'date': u'2016-03-21', 'regressionmodel': 'lrm', 'predictprice': 105.907309064562, 'trueprice': 120.76499949999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 83, '_source': {'date': u'2016-03-22', 'regressionmodel': 'lrm', 'predictprice': 106.71728545376473, 'trueprice': 116.83499950000001}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 84, '_source': {'date': u'2016-03-23', 'regressionmodel': 'lrm', 'predictprice': 106.12729646672507, 'trueprice': 116.240002}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 85, '_source': {'date': u'2016-03-24', 'regressionmodel': 'lrm', 'predictprice': 105.66730917164018, 'trueprice': 115.9900015}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 86, '_source': {'date': u'2016-03-28', 'regressionmodel': 'lrm', 'predictprice': 105.18732538538941, 'trueprice': 113.76999649999999}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 87, '_source': {'date': u'2016-03-29', 'regressionmodel': 'lrm', 'predictprice': 107.67726002608815, 'trueprice': 112.7799985}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 88, '_source': {'date': u'2016-03-30', 'regressionmodel': 'lrm', 'predictprice': 109.55721018855587, 'trueprice': 114.305}, '_index': 'regressionpredict'}
# {'_type': u'AAPL.csv', '_id': 89, '_source': {'date': u'2016-03-31', 'regressionmodel': 'lrm', 'predictprice': 108.98722469250396, 'trueprice': 116.5250015}, '_index': 'regressionpredict'}
# =======es writing pass=======
